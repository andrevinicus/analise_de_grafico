# %% [markdown]
# <a href="https://colab.research.google.com/github/andrevinicus/analise_de_grafico/blob/main/Tipos_de_Gr%C3%A1ficos_Roteiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Roteiro para Criação de Gráficos

# %%
# !pip install -U --no-cache-dir gdown --pre

# %%
import gdown
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !gdown 1GZkHDnV3fMCSFvvKSyPP14AFMdEfqacx
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GZkHDnV3fMCSFvvKSyPP14AFMdEfqacx
# To: d:\Area de trabalho\vendas_produtos.csv
#
#   0%|          | 0.00/227 [00:00<?, ?B/s]
# 100%|██████████| 227/227 [00:00<?, ?B/s]

# %%
df = pd.read_csv('vendas_produtos.csv')
df
# Out:
#    Meses  Produto 1  Produto 2  Produto 3
# 0    Jan        120        100         90
# 1    Fev        150        130        110
# 2    Mar        170        165        140
# 3    Abr        200        195        180
# 4    Mai        165        175        170
# 5    Jun        180        180        175
# 6    Jul        220        215        205
# 7    Ago        230        225        210
# 8    Set        210        210        200
# 9    Out        210        200        190
# 10   Nov        240        230        215
# 11   Dez        260        250        230

# %%
#estilo de cor
plt.style.use('ggplot') 

# Aumentar o tamanho da fonte
plt.rcParams.update({'font.size': 16})

# Criar um gráfico de linha
plt.figure(figsize=(16, 12))

#descompactar lista
produto1, = plt.plot(df['Meses'], df['Produto 1'], label='Produto 1', marker='o') 
produto2, = plt.plot(df['Meses'], df['Produto 2'], label='Produto 2', marker='o')
produto3, = plt.plot(df['Meses'], df['Produto 3'], label='Produto 3', marker='o')


plt.legend([produto1, produto2, produto3], ['Produto 1', 'Produto 2', 'Produto 3'])
plt.title('Vendas de Produtos (2023)')
plt.xlabel('Mês')
plt.ylabel('Vendas')

plt.savefig('GraficoLinha.svg')
# Mostrar o gráfico
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # Mude o estilo do gráfico de linhas por seu estilo favorito:

# %%
#estilo de cor
plt.style.use('dark_background') 

# Aumentar o tamanho da fonte
plt.rcParams.update({'font.size': 16})

# Criar um gráfico de linha
plt.figure(figsize=(16, 12))

#descompactar lista
produto1, = plt.plot(df['Meses'], df['Produto 1'], label='Produto 1', marker='o') 
produto2, = plt.plot(df['Meses'], df['Produto 2'], label='Produto 2', marker='o')
produto3, = plt.plot(df['Meses'], df['Produto 3'], label='Produto 3', marker='o')


plt.legend([produto1, produto2, produto3], ['Produto 1', 'Produto 2', 'Produto 3'])
plt.title('Vendas de Produtos (2023)')
plt.xlabel('Mês')
plt.ylabel('Vendas')

plt.savefig('GraficoLinha.svg')
# Mostrar o gráfico
plt.show()

# %% [markdown]
# #Crie uma função para realizar o gráfico de linhas passando como parâmetro o estilo
#
# # def GraficoLinha(style)

# %%
 def GraficoLinha(style='ggplot'):
  #estilo de cor
  plt.style.use('ggplot') 

  # Aumentar o tamanho da fonte
  plt.rcParams.update({'font.size': 16})

  # Criar um gráfico de linha
  plt.figure(figsize=(16, 12))

  #descompactar lista
  produto1, = plt.plot(df['Meses'], df['Produto 1'], label='Produto 1', marker='o') 
  produto2, = plt.plot(df['Meses'], df['Produto 2'], label='Produto 2', marker='o')
  produto3, = plt.plot(df['Meses'], df['Produto 3'], label='Produto 3', marker='o')


  plt.legend([produto1, produto2, produto3], ['Produto 1', 'Produto 2', 'Produto 3'])
  plt.title('Vendas de Produtos (2023)')
  plt.xlabel('Mês')
  plt.ylabel('Vendas')

  plt.savefig('GraficoLinha.svg')
  # Mostrar o gráfico
  plt.show()

# %% [markdown]
# # Agora faça o mesmo para o gráfico de barras

# %%
# !gdown 1GfjQWcme9Jbs3yCns6o_UzxKhg6cGleV
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GfjQWcme9Jbs3yCns6o_UzxKhg6cGleV
# To: d:\Area de trabalho\Produtos_cat_vend.csv
#
#   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# 100%|██████████| 86.0/86.0 [00:00<?, ?B/s]

# %%
df = pd.read_csv('Produtos_cat_vend.csv')
df
# Out:
#     Produtos  Vendas
# 0  Produto 1     123
# 1  Produto 2     432
# 2  Produto 3     331
# 3  Produto 4     456
# 4  Produto 5     231

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Criar o gráfico de barras
def GraficoLinha(style='ggplot'):
    #plt.bar(df['Produtos'], df['Vendas'])
    #Barra Horizontal
    plt.barh(df['Produtos'], df['Vendas'])
    

    plt.title('Vendas de Produtos')
    plt.xlabel('Produto')
    plt.ylabel('Quantidade Vendida')

    # Mostrar o gráfico
    plt.show()

# %%
GraficoLinha('dark_background')

# %% [markdown]
# # Gráfico de Dispersão
# ## Crie uma função

# %%
# !gdown 1GijLvrGSDA5GHVZw8TlZ3cDZXRIjCw2j
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GijLvrGSDA5GHVZw8TlZ3cDZXRIjCw2j
# To: d:\Area de trabalho\Idade_Carro.csv
#
#   0%|          | 0.00/97.0 [00:00<?, ?B/s]
# 100%|██████████| 97.0/97.0 [00:00<?, ?B/s]

# %%
df = pd.read_csv('Idade_Carro.csv')
df
# Out:
#     Idade  Preço
# 0       5   9500
# 1       7   7000
# 2       8   6300
# 3      10   5500
# 4      12   4800
# 5      15   3900
# 6      20   2800
# 7      22   2200
# 8      24   1800
# 9      26   1500
# 10     30    800

# %%
# Criar o gráfico de dispersão
def GraficoLinha(style='ggplot'):
    plt.scatter(df['Idade'], df['Preço'])

    plt.title('Preço do Carro x Idade')
    plt.xlabel('Idade do Carro (Anos)')
    plt.ylabel('Preço (R$)')

    # Mostrar o gráfico
    plt.show()

# %%
GraficoLinha('dark_background')

# %% [markdown]
# # Explique como esse gráfico:

# %% [markdown]
# # Por que é interessante fazer um gráfico de dispersão nesse caso?
# R:

# %% [markdown]
# Fazer um gráfico de dispersão é interessante porque ele permite visualizar a relação entre duas variáveis diferentes de forma rápida e fácil. Ele ajuda a identificar padrões e tendências nos dados, além de verificar se existe uma relação entre as variáveis e qual é a natureza dessa relação. É uma ferramenta útil para análise exploratória de dados e tomada de decisões informadas.

# %% [markdown]
# # Qual é a diferença entre o gráfico de linha na interpretação?
# R:Um gráfico de dispersão mostra a relação entre duas variáveis quantitativas, usando pontos no gráfico. Ele ajuda a identificar padrões e tendências na relação entre as variáveis. Já um gráfico de linha é usado para representar a mudança de uma variável ao longo do tempo ou de outra escala contínua. Ele é útil para mostrar tendências temporais.

# %% [markdown]
# # Historiograma

# %% [markdown]
# ## Modifique a distribuição aleatória para distribuição normal - Pesquise a função numpy

# %%
# Vamos gerar um conjunto de dados aleatórios para as idades
np.random.seed(0)
idades = np.random.normal(0, 100, size=1000) #distribuição aleatória de valor inteiro

# Criar o histograma
plt.hist(idades, bins=20, edgecolor='black')

plt.title('Distribuição das Idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Interprete a distribuição distribuição e compare a diferença com a distribuição normal
#
# R:A distribuição gerada para as idades segue uma distribuição normal, caracterizada por uma forma de sino. Isso indica que há uma concentração maior de valores em torno da média e uma diminuição gradual das frequências em direção às extremidades. Em comparação com a distribuição uniforme, a distribuição normal apresenta uma distribuição mais concentrada em torno de um valor central, em vez de ser igualmente distribuída em todas as faixas de idade.

# %% [markdown]
# # Gráfico de Donut

# %%
# Dados
generos = ['Feminino', 'Masculino']
quantidade = [650, 550]

# %%
# Criar o gráfico de pizza
plt.pie(quantidade, labels=generos, autopct='%1.1f%%', startangle=90, colors=['#FFC0CB', '#0000FF'], wedgeprops={'width': 0.4})

plt.title('Distribuição de Gênero')


# Mostrar o gráfico
plt.show()

# %% [markdown]
# # DESAFIO
#
# Deixe o gráfico dessa maneira:
#
# ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(10, 20))
plt.pie(quantidade, labels=generos, autopct='%1.1f%%', startangle=90, colors=['#FFC0CB', '#0000FF'], wedgeprops={'width': 0.2})


plt.title('Distribuição de Gênero')


# Mostrar o gráfico
plt.show()

# %%
plt.figure(figsize=(10, 10))
explode = [0.1, 0]
labeldistance = 1.5
plt.pie(quantidade, labels=generos, autopct='%1.1f%%', startangle=84, colors=['#FFC0CB', '#0000FF'], wedgeprops={'width': 0.3}, pctdistance=1.3, radius=0.7, labeldistance=labeldistance)

plt.legend(fontsize='medium')  # Aumentar o tamanho da descrição dos gêneros
plt.show()

# %%
plt.figure(figsize=(15, 15), facecolor='#3d4654') 
labeldistance = 1.5 # Ajustar a distância dos rótulos em relação ao centro
pie = plt.pie(quantidade, labels=generos, autopct='%1.1f%%', startangle=84, colors=['#FFC0CB', '#0000FF'], wedgeprops={'width': 0.3}, pctdistance=1.3, radius=0.7, labeldistance=labeldistance)

plt.legend(fontsize='large')  # Aumentar o tamanho da descrição dos gêneros

plt.title('Distribuição de Gênero')
# Aumentar o tamanho da fonte dos rótulos das categorias específicas
texts = pie[1]
texts[generos.index('Feminino')].set_fontsize(20)
texts[generos.index('Masculino')].set_fontsize(20)
texts = pie[2]
texts[generos.index('Feminino')].set_fontsize(20)
texts[generos.index('Masculino')].set_fontsize(20)
plt.show()

# %% [markdown]
# # Gráfico de Caixa (Box Plot)

# %%
# Dados
distribuicao = np.random.normal(40, 20, 120)

# Criar o gráfico de caixa
plt.boxplot(distribuicao)

plt.title('Distribuição Personalizada')
plt.xlabel('Dados')
plt.ylabel('Valores')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Explique o Gráfico acima -- Pesquise
# R:O gráfico de caixa representa a distribuição dos dados. O retângulo central indica o intervalo interquartil (IQR), que contém a maioria dos dados (50%). A linha dentro do retângulo representa a mediana. Os "bigodes" indicam a amplitude dos dados, excluindo os possíveis valores discrepantes (outliers).

# %% [markdown]
# # Diagrama de Violino

# %%
# !gdown 1GvcLp9qKfSI2o0CHvXjsGXDRTZ91SGy9
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GvcLp9qKfSI2o0CHvXjsGXDRTZ91SGy9
# To: d:\Downloads\Pontuacao.csv
#
#   0%|          | 0.00/7.21k [00:00<?, ?B/s]
# 100%|██████████| 7.21k/7.21k [00:00<?, ?B/s]

# %%
df = pd.read_csv('Pontuacao.csv')
df
# Out:
#      Equipe A   Equipe B   Equipe C    Equipe D
# 0   77.167926  66.463595  84.559014  106.970881
# 1   76.764764  74.350674  60.319876   87.518938
# 2   78.553779  67.191898  75.061567   98.556478
# 3   95.368871  74.888618  85.402054   86.279746
# 4   77.728494  70.933726  66.396115   76.258294
# ..        ...        ...        ...         ...
# 95  90.423557  78.783529  92.011516   83.443977
# 96  84.609794  74.999238  90.105536   87.627799
# 97  76.816536  76.896912  85.177010   83.862049
# 98  76.153257  80.493461  90.174774   91.256109
# 99  78.244719  71.860788  96.877019   80.089023
#
# [100 rows x 4 columns]

# %%
# Criar o gráfico de violino
equipes = df.columns.tolist()
plt.figure(figsize=(8, 6))
plt.violinplot(df)

# Personalizar o gráfico
plt.title('Distribuição da Pontuação por Equipe')
plt.xlabel('Equipes')
plt.ylabel('Pontuação')

plt.xticks(np.arange(1, len(equipes)+1), equipes)

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Explique o gráfico acima, qual é a diferença da Equipe C da Equipe D.
# R:O gráfico de violino acima mostra a distribuição da pontuação para cada equipe. Ele combina elementos do boxplot e do kernel density plot para fornecer uma representação detalhada da distribuição dos dados. A diferença entre a Equipe C e a Equipe D pode ser visualizada observando a forma e a densidade dos violinos correspondentes a cada equipe, assim vendo que a equipe d com media entre 90 e 100, sendo que a pontuaçao da equipe D começa pelo 70 porem acaba entre 110, tanto a equipe C variando entre 60 ate em torno de 125 com mediana de 90.
# Podenos concluir que a dencidade da equipe D em pontuaçao e maior que a C
